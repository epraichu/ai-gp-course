# %% [markdown]
# <a href="https://colab.research.google.com/github/epraichu/ai-gp-course/blob/main/lesson9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {'A': 25, 'B': 30, 'C': 40}
s = pd.Series(data)
print(s)
# Out:
# A    25
# B    30
# C    40
# dtype: int64

# %%
import numpy as np

s2 = pd.Series([10, 20, 22, 40, np.nan], index=['A', 'B', 'C', 'D', 'E'])
print(s2)

print(s.size)
print(s.shape)
print(s.dtype)
print(s.index)
print(s.values)
print(s['C'])
print(s.iloc[0])
# Out:
# A    10.0
# B    20.0
# C    22.0
# D    40.0
# E     NaN
# dtype: float64
# 3
# (3,)
# int64
# Index(['A', 'B', 'C'], dtype='object')
# [25 30 40]
# 40
# 25

# %%
data = {
    "cena": [20, 10, 23],
    "ilość": [65, 38, 45]
}
df = pd.DataFrame(data, index = ["Produkt A", "produkt B", "produkt C"])

df
# Out:
#            cena  ilość
# Produkt A    20     65
# produkt B    10     38
# produkt C    23     45

# %%
print(df.loc["Produkt A"])
# Out:
# cena     20
# ilość    65
# Name: Produkt A, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Produkt A to produkt C
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cena    3 non-null      int64
#  1   ilość   3 non-null      int64
# dtypes: int64(2)
# memory usage: 180.0+ bytes
# None

# %%
df = pd.read_excel("Gigathon_Wyniki.xlsx")
# df

# %%
print(df.head(4))
print(df.tail(5))
# Out:
#         Imię  Wiek  Punktacja
# 0     Łukasz    18       51.0
# 1  Magdalena    18       52.0
# 2   Radosław    15       46.0
# 3     Patryk    15       52.0
#          Imię  Wiek  Punktacja
# 20        Iga    15       77.0
# 21    Urszula    14      102.0
# 22        Jan    17      102.0
# 23     Michał    15        NaN
# 24  Katarzyna    18       68.0

# %%
df["Wynik procentowy"] = df["Punktacja"]/120*100

# %%
df.dropna(inplace=True)

# %%
df.sort_values(by="Punktacja", ascending=False, inplace=True)

# %%
df["Zakwalifikowany"] = df["Wynik procentowy"] >=70

# %%
df.groupby(["Zakwalifikowany", "Wiek"])[["Punktacja", "Wynik procentowy"]].agg(["count", "min", "max", "mean", "median"])
# Out:
#                      Punktacja                                   \
#                          count    min    max        mean median
# Zakwalifikowany Wiek
# False           13           1   70.0   70.0   70.000000   70.0
#                 14           1   63.0   63.0   63.000000   63.0
#                 15           3   46.0   77.0   58.333333   52.0
#                 16           1   61.0   61.0   61.000000   61.0
#                 17           1   39.0   39.0   39.000000   39.0
#                 18           3   51.0   68.0   57.000000   52.0
# True            14           3   84.0  110.0   98.666667  102.0
#                 15           1  120.0  120.0  120.000000  120.0
#                 16           3   92.0  112.0  101.333333  100.0
#                 17           4   97.0  104.0  100.250000  100.0
#
#                      Wynik procentowy                                      \
#                                 count         min         max        mean
# Zakwalifikowany Wiek
# False           13                  1   58.333333   58.333333   58.333333
#                 14                  1   52.500000   52.500000   52.500000
#                 15                  3   38.333333   64.166667   48.611111
#                 16                  1   50.833333   50.833333   50.833333
#                 17                  1   32.500000   32.500000   32.500000
#                 18                  3   42.500000   56.666667   47.500000
# True            14                  3   70.000000   91.666667   82.222222
#                 15                  1  100.000000  100.000000  100.000000
#                 16                  3   76.666667   93.333333   84.444444
#                 17                  4   80.833333   86.666667   83.541667
#
#
#                           median
# Zakwalifikowany Wiek
# False           13     58.333333
#                 14     52.500000
#                 15     43.333333
#                 16     50.833333
#                 17     32.500000
#                 18     43.333333
# True            14     85.000000
#                 15    100.000000
#                 16     83.333333
#                 17     83.333333

# %%
df_zakwalifikowani = df[df["Zakwalifikowany"]]
df_niezakwalifikowani = df[~df["Zakwalifikowany"]]

#df_zakwalifikowani.to_excel("zakwalifikowani.xlsx")
#df_niezakwalifikowani.to_excel("niezakwalifikowani.xlsx")
