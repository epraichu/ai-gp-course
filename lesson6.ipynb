# %%
print(123)
# Out:
# 123

# %%
num = 10
float_num = 5.50
text = "Hello"
bool_variable = False

print(text)

print(f"liczba: {num}, średnia: {float_num}")
print(type(num))
# Out:
# Hello
# liczba: 10, średnia: 5.5
# <class 'int'>

# %%
games = ["Prison Architect", "Pimworld", "Life is strange"]
print(games)
print(games[2])

games.append("Hell Let Loose")

print(games)
# Out:
# ['Prison Architect', 'Pimworld', 'Life is strange']
# Life is strange
# ['Prison Architect', 'Pimworld', 'Life is strange', 'Hell Let Loose']

# %%
print(int("011110", 2))
print(int("FF", 16))
print(int("321", 4))
# Out:
# 30
# 255
# 57

# %%
temperature = float(input("Podaj temperaturę: "))

if temperature < 20:
  print("Podwyższam temperaturę")
elif temperature > 22:
  print("Wyłączam grzejnik")
else:
  print("Temperatura w normie")
# Out:
# Podaj temperaturę: 18
# Podwyższam temperaturę

# %%
for game in games:
  print(game)

for i in range(5):
  print(i)

for i in range(-8, 19, 3):
  print(i)

def add(a, b):
  print(a+b)

add(9, 19)
# Out:
# Prison Architect
# Pimworld
# Life is strange
# Hell Let Loose
# 0
# 1
# 2
# 3
# 4
# -8
# -5
# -2
# 1
# 4
# 7
# 10
# 13
# 16
# 28
