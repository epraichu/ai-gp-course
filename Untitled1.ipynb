# %% [markdown]
# <a href="https://colab.research.google.com/github/epraichu/ai-gp-course/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

fig, axes = plt.subplots(nrows = 10, ncols=5, figsize=(7,14))
rng = np.random.default_rng()

for digit in range(10):
  idx = np.where(y_train == digit)[0]
  choosen = rng.choice(idx, size=5, replace=False)

  for col, img_idx in enumerate(choosen):
    ax = axes[digit, col]
    ax.imshow(x_train[img_idx], cmap="gray")
    ax.axis("off")

plt.show()

# %%
from tensorflow.keras.utils import to_categorical
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

print("Po monrmalizacji: min/max x_train:", x_train.min(), x_train.max(), "dtype:", x_train.dtype)

x_train = x_train[..., np.newaxis]
x_test = x_test[..., np.newaxis]

print("Po dodaniu kanały:", x_train.shape, x_test.shape)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# Po monrmalizacji: min/max x_train: 0.0 1.0 dtype: float32
# Po dodaniu kanały: (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Sequential

model = Sequential([
    layers.Flatten(input_shape=(28,28,1)),
    layers.Dense(512, activation="relu"),
    layers.Dense(256, activation="relu"),
    layers.Dense(10, activation="softmax"),
])

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.1)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.8981 - loss: 0.3349 - val_accuracy: 0.9668 - val_loss: 0.1084
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9739 - loss: 0.0841 - val_accuracy: 0.9765 - val_loss: 0.0785
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9818 - loss: 0.0583 - val_accuracy: 0.9775 - val_loss: 0.0735
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - accuracy: 0.9885 - loss: 0.0370 - val_accuracy: 0.9780 - val_loss: 0.0765
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9906 - loss: 0.0304 - val_accuracy: 0.9798 - val_loss: 0.0694
# Epoch 6/10
# ...

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Strata: {loss:.4f}, Dokładność: {accuracy:.4f}")
# Out:
# Strata: 0.0837, Dokładność: 0.9834
